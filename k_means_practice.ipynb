# %% [markdown]
# <a href="https://colab.research.google.com/github/Ravindrakumarnayak/Machine_learning/blob/main/k_means_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# %%
Univ=pd.read_csv("/content/Universities.csv")
Univ
# Out:
#             Univ   SAT  Top10  Accept  SFRatio  Expenses  GradRate
# 0          Brown  1310     89      22       13     22704        94
# 1        CalTech  1415    100      25        6     63575        81
# 2            CMU  1260     62      59        9     25026        72
# 3       Columbia  1310     76      24       12     31510        88
# 4        Cornell  1280     83      33       13     21864        90
# 5      Dartmouth  1340     89      23       10     32162        95
# 6           Duke  1315     90      30       12     31585        95
# 7     Georgetown  1255     74      24       12     20126        92
# 8        Harvard  1400     91      14       11     39525        97
# 9   JohnsHopkins  1305     75      44        7     58691        87
# 10           MIT  1380     94      30       10     34870        91
# 11  Northwestern  1260     85      39       11     28052        89
# 12     NotreDame  1255     81      42       13     15122        94
# ...

# %%
Univ.head()
# Out:
#        Univ   SAT  Top10  Accept  SFRatio  Expenses  GradRate
# 0     Brown  1310     89      22       13     22704        94
# 1   CalTech  1415    100      25        6     63575        81
# 2       CMU  1260     62      59        9     25026        72
# 3  Columbia  1310     76      24       12     31510        88
# 4   Cornell  1280     83      33       13     21864        90

# %%
Univ.tail()
# Out:
#           Univ   SAT  Top10  Accept  SFRatio  Expenses  GradRate
# 20   UMichigan  1180     65      68       16     15470        85
# 21       UPenn  1285     80      36       11     27553        90
# 22         UVA  1225     77      44       14     13349        92
# 23  UWisconsin  1085     40      69       15     11857        71
# 24        Yale  1375     95      19       11     43514        96

# %%
Univ.shape
# Out:
# (25, 7)

# %%
Univ.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Univ      25 non-null     object
#  1   SAT       25 non-null     int64
#  2   Top10     25 non-null     int64
#  3   Accept    25 non-null     int64
#  4   SFRatio   25 non-null     int64
#  5   Expenses  25 non-null     int64
#  6   GradRate  25 non-null     int64
# dtypes: int64(6), object(1)
# memory usage: 1.5+ KB

# %%
#elbow method

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
scaled_Univ_df= scaler.fit_transform(Univ.iloc[:,1:])
scaled_Univ_df
# Out:
# array([[ 0.41028362,  0.6575195 , -0.88986682,  0.07026045, -0.33141256,
#          0.82030265],
#        [ 1.39925928,  1.23521235, -0.73465749, -1.68625071,  2.56038138,
#         -0.64452351],
#        [-0.06065717, -0.76045386,  1.02438157, -0.93346022, -0.16712136,
#         -1.65863393],
#        [ 0.41028362, -0.02520842, -0.78639393, -0.18066972,  0.29164871,
#          0.14422904],
#        [ 0.12771914,  0.34241431, -0.32076595,  0.07026045, -0.39084607,
#          0.36958691],
#        [ 0.69284809,  0.6575195 , -0.83813038, -0.68253005,  0.33778044,
#          0.93298158],
#        [ 0.4573777 ,  0.71003703, -0.47597528, -0.18066972,  0.29695528,
#          0.93298158],
#        [-0.10775125, -0.13024348, -0.78639393, -0.18066972, -0.51381683,
#          0.59494478],
#        [ 1.25797704,  0.76255456, -1.30375836, -0.43159988,  0.85874344,
#          1.15833946],
#        [ 0.36318954, -0.07772595,  0.24833493, -1.43532055,  2.21481798,
#          0.0315501 ],
# ...

# %%
wcss=[]
for i in range(1,11):
  kmeans=KMeans(n_clusters=i,init='k-means++',max_iter=300, random_state=0)
  kmeans.fit(scaled_Univ_df)
  wcss.append(kmeans.inertia_)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# ...

# %%
plt.plot(range(1,11),wcss)
plt.title("Elbow Method")
plt.xlabel("number of clusters")
plt.ylabel("wcss")
plt.show()

# %%
wcss
# Out:
# [150.0,
#  64.1452839501027,
#  44.531761731450956,
#  33.654341806512235,
#  26.9536816278831,
#  23.028199078329926,
#  18.56891703085987,
#  16.301664640974554,
#  13.47880438976081,
#  10.640545447539141]

# %%
#for clusters=4

# %%
kmeans=KMeans(n_clusters=4, random_state=0)
predict=kmeans.fit_predict(scaled_Univ_df)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
kmeans
# Out:
# KMeans(n_clusters=4, random_state=0)

# %%
predict
# Out:
# array([2, 3, 0, 2, 0, 2, 2, 0, 2, 3, 2, 0, 0, 1, 2, 1, 2, 1, 0, 0, 0, 0,
#        0, 1, 2], dtype=int32)

# %%
# clusters=3

# %%
kmeans_more=KMeans(n_clusters=3, random_state=0)
predict_new=kmeans_more.fit_predict(scaled_Univ_df)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
predict_new
# Out:
# array([2, 0, 2, 2, 2, 0, 0, 2, 0, 0, 0, 2, 2, 1, 0, 1, 0, 1, 2, 2, 2, 2,
#        2, 1, 0], dtype=int32)

# %%
Univ['univ_new']=predict_new
Univ
# Out:
#             Univ   SAT  Top10  Accept  SFRatio  Expenses  GradRate  univ_new
# 0          Brown  1310     89      22       13     22704        94         2
# 1        CalTech  1415    100      25        6     63575        81         0
# 2            CMU  1260     62      59        9     25026        72         2
# 3       Columbia  1310     76      24       12     31510        88         2
# 4        Cornell  1280     83      33       13     21864        90         2
# 5      Dartmouth  1340     89      23       10     32162        95         0
# 6           Duke  1315     90      30       12     31585        95         0
# 7     Georgetown  1255     74      24       12     20126        92         2
# 8        Harvard  1400     91      14       11     39525        97         0
# 9   JohnsHopkins  1305     75      44        7     58691        87         0
# 10           MIT  1380     94      30       10     34870        91         0
# ...

# %%
Univ.groupby("univ_new").agg(['mean']).reset_index()
# Out:
# <ipython-input-24-1d333a767ba4>:1: FutureWarning: ['Univ'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   Univ.groupby("univ_new").agg(['mean']).reset_index()
#   univ_new          SAT      Top10     Accept    SFRatio      Expenses  \
#                    mean       mean       mean       mean          mean
# 0        0  1362.777778  90.555556  24.333333   9.666667  41176.888889
# 1        1  1061.500000  38.750000  70.000000  19.250000   9953.000000
# 2        2  1262.500000  78.500000  40.083333  12.833333  22858.000000
#
#     GradRate
#         mean
# 0  92.222222
# 1  71.750000
# 2  87.583333

# %%
Univ[Univ['univ_new']==0].shape[0]
# Out:
# 9

# %%
Univ[Univ['univ_new']==1].shape[0]
# Out:
# 4

# %%
Univ[Univ['univ_new']==2].shape[0]
# Out:
# 12
