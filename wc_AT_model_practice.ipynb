# %% [markdown]
# <a href="https://colab.research.google.com/github/Ravindrakumarnayak/Machine_learning/blob/main/wc_AT_model_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

import matplotlib.pyplot as plt

# %%
df=pd.read_csv("/content/WC_AT.csv")
df
# Out:
#       Waist      AT
# 0     74.75   25.72
# 1     72.60   25.89
# 2     81.80   42.60
# 3     83.95   42.80
# 4     74.65   29.84
# ..      ...     ...
# 104  100.10  124.00
# 105   93.30   62.20
# 106  101.80  133.00
# 107  107.90  208.00
# 108  108.50  208.00
#
# [109 rows x 2 columns]

# %%
df.shape
# Out:
# (109, 2)

# %%
df.describe()
# Out:
#             Waist          AT
# count  109.000000  109.000000
# mean    91.901835  101.894037
# std     13.559116   57.294763
# min     63.500000   11.440000
# 25%     80.000000   50.880000
# 50%     90.800000   96.540000
# 75%    104.000000  137.000000
# max    121.000000  253.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 109 entries, 0 to 108
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Waist   109 non-null    float64
#  1   AT      109 non-null    float64
# dtypes: float64(2)
# memory usage: 1.8 KB

# %%
df.boxplot('Waist','AT')
# Out:
# <Axes: title={'center': 'Waist'}, xlabel='AT'>

# %%
import statsmodels.formula.api as smf
model=smf.ols('AT~Waist',data=df).fit()

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                     AT   R-squared:                       0.670
# Model:                            OLS   Adj. R-squared:                  0.667
# Method:                 Least Squares   F-statistic:                     217.3
# Date:                Thu, 20 Jul 2023   Prob (F-statistic):           1.62e-27
# Time:                        10:48:15   Log-Likelihood:                -534.99
# No. Observations:                 109   AIC:                             1074.
# Df Residuals:                     107   BIC:                             1079.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   -215.9815     21.796     -9.909      0.000    -259.190    -172.773
# ...

# %%
model.predict(df,'Waist')
# Out:
# 0       42.568252
# 1       35.131704
# 2       66.953210
# 3       74.389758
# 4       42.222366
#           ...
# 104    130.250337
# 105    106.730093
# 106    136.130398
# 107    157.229440
# 108    159.304756
# Length: 109, dtype: float64

# %%
model.resid
# Out:
# 0     -16.848252
# 1      -9.241704
# 2     -24.353210
# 3     -31.589758
# 4     -12.382366
#          ...
# 104    -6.250337
# 105   -44.530093
# 106    -3.130398
# 107    50.770560
# 108    48.695244
# Length: 109, dtype: float64

# %%
df
# Out:
#       Waist      AT
# 0     74.75   25.72
# 1     72.60   25.89
# 2     81.80   42.60
# 3     83.95   42.80
# 4     74.65   29.84
# ..      ...     ...
# 104  100.10  124.00
# 105   93.30   62.20
# 106  101.80  133.00
# 107  107.90  208.00
# 108  108.50  208.00
#
# [109 rows x 2 columns]

# %%
plt.scatter(x=df['Waist'],y=df['AT'])

# %%
import numpy as np

model2=smf.ols('AT~np.log(Waist)',data=df).fit()
model2

# %%
model2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                     AT   R-squared:                       0.675
# Model:                            OLS   Adj. R-squared:                  0.672
# Method:                 Least Squares   F-statistic:                     222.6
# Date:                Thu, 20 Jul 2023   Prob (F-statistic):           6.80e-28
# Time:                        10:56:26   Log-Likelihood:                -534.11
# No. Observations:                 109   AIC:                             1072.
# Df Residuals:                     107   BIC:                             1078.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# ...

# %%
model2=smf.ols('np.log(AT)~Waist',data=df).fit()
model2

# %%
model2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:             np.log(AT)   R-squared:                       0.707
# Model:                            OLS   Adj. R-squared:                  0.704
# Method:                 Least Squares   F-statistic:                     258.3
# Date:                Thu, 20 Jul 2023   Prob (F-statistic):           2.68e-30
# Time:                        10:59:59   Log-Likelihood:                -40.123
# No. Observations:                 109   AIC:                             84.25
# Df Residuals:                     107   BIC:                             89.63
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.7410      0.233      3.185      0.002       0.280       1.202
# ...
